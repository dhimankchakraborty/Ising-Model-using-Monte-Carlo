# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
concentration_array_10 = np.load("concentration_array_10.npy")
temp_array_10 = np.load("temp_array_10.npy")
magnetization_v_temp_arr_10 = np.load("magnetization_v_temp_arr_10.npy")
energy_v_temp_arr_10 = np.load("energy_v_temp_arr_10.npy")
specific_heat_v_temp_arr_10 = np.load("specific_heat_v_temp_arr_10.npy")
susceptibility_v_temp_arr_10 = np.load("susceptibility_v_temp_arr_10.npy")

concentration_array_15 = np.load("concentration_array_15.npy")
temp_array_15 = np.load("temp_array_15.npy")
magnetization_v_temp_arr_15 = np.load("magnetization_v_temp_arr_15.npy")
energy_v_temp_arr_15 = np.load("energy_v_temp_arr_15.npy")
specific_heat_v_temp_arr_15 = np.load("specific_heat_v_temp_arr_15.npy")
susceptibility_v_temp_arr_15 = np.load("susceptibility_v_temp_arr_15.npy")

concentration_array_20 = np.load("concentration_array_20.npy")
temp_array_20 = np.load("temp_array_20.npy")
magnetization_v_temp_arr_20 = np.load("magnetization_v_temp_arr_20.npy")
energy_v_temp_arr_20 = np.load("energy_v_temp_arr_20.npy")
specific_heat_v_temp_arr_20 = np.load("specific_heat_v_temp_arr_20.npy")
susceptibility_v_temp_arr_20 = np.load("susceptibility_v_temp_arr_20.npy")

# %%
concentration_array = concentration_array_10
temp_array = temp_array_10
magnetization_v_temp_arr = magnetization_v_temp_arr_10
energy_v_temp_arr = energy_v_temp_arr_10
specific_heat_v_temp_arr = specific_heat_v_temp_arr_10
susceptibility_v_temp_arr = susceptibility_v_temp_arr_10

# print(concentration_array)

select_conc_vals = np.array([1, 0.8, 0.6, 0.4, 0.2])
select_conc_idx = np.where(np.isin(concentration_array, select_conc_vals))[0]

# print(select_conc_vals)
# print(select_conc_idx)
# print(type(select_conc_idx))

plot_no = 1

plt.tight_layout()
# print(magnetization_v_temp_arr)

for step in select_conc_idx:
    plt.plot(temp_array, np.abs(magnetization_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Magnetization per Particle vs Temperature \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(magnetization_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Magnetization per Particle vs Concentration \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(energy_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Energy per Particle vs Temperature \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(energy_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Energy per Particle vs Concentration \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array[1:-1], np.abs(specific_heat_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Specific Heat vs Temperature \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)
# print(select_temp_idx)
for step in select_temp_idx[:-1]:
    plt.plot(concentration_array, np.abs(specific_heat_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Specific Heat vs Concentration \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(susceptibility_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Susceptibility vs Temperature \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(susceptibility_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Susceptibility vs Concentration \nSystem Size (L): {10}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

# %%
concentration_array = concentration_array_15
temp_array = temp_array_15
magnetization_v_temp_arr = magnetization_v_temp_arr_15
energy_v_temp_arr = energy_v_temp_arr_15
specific_heat_v_temp_arr = specific_heat_v_temp_arr_15
susceptibility_v_temp_arr = susceptibility_v_temp_arr_15


select_conc_vals = np.array([1, 0.8, 0.6, 0.4, 0.2])
select_conc_idx = np.where(np.isin(concentration_array, select_conc_vals))[0]


plt.tight_layout()
# print(magnetization_v_temp_arr)

for step in select_conc_idx:
    plt.plot(temp_array, np.abs(magnetization_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Magnetization per Particle vs Temperature \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(magnetization_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Magnetization per Particle vs Concentration \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(energy_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Energy per Particle vs Temperature \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(energy_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Energy per Particle vs Concentration \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array[1:-1], np.abs(specific_heat_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Specific Heat vs Temperature \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)
# print(select_temp_idx)
for step in select_temp_idx[:-1]:
    plt.plot(concentration_array, np.abs(specific_heat_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Specific Heat vs Concentration \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(susceptibility_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Susceptibility vs Temperature \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(susceptibility_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Susceptibility vs Concentration \nSystem Size (L): {15}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

# %%
concentration_array = concentration_array_20
temp_array = temp_array_20
magnetization_v_temp_arr = magnetization_v_temp_arr_20
energy_v_temp_arr = energy_v_temp_arr_20
specific_heat_v_temp_arr = specific_heat_v_temp_arr_20
susceptibility_v_temp_arr = susceptibility_v_temp_arr_20


select_conc_vals = np.array([1, 0.8, 0.6, 0.4, 0.2])
select_conc_idx = np.where(np.isin(concentration_array, select_conc_vals))[0]


plt.tight_layout()
# print(magnetization_v_temp_arr)

for step in select_conc_idx:
    plt.plot(temp_array, np.abs(magnetization_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Magnetization per Particle vs Temperature \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(magnetization_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Magnetization per Particle vs Concentration \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Magnetization per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(energy_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Energy per Particle vs Temperature \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(energy_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Energy per Particle vs Concentration \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Energy per Particle")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array[1:-1], np.abs(specific_heat_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Specific Heat vs Temperature \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)
# print(select_temp_idx)
for step in select_temp_idx[:-1]:
    plt.plot(concentration_array, np.abs(specific_heat_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Specific Heat vs Concentration \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Specific Heat")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()


for step in select_conc_idx:
    plt.plot(temp_array, np.abs(susceptibility_v_temp_arr[step]), label= f'x: {concentration_array[step]}')
plt.title(f"Susceptibility vs Temperature \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Temperature (T)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()

select_temp_idx = np.where(np.isin(temp_array, np.array([0.2, 1, 2])))[0]
# print(temp_array)

for step in select_temp_idx:
    plt.plot(concentration_array, np.abs(susceptibility_v_temp_arr[:,step]), label= f'T: {temp_array[step]}')
plt.title(f"Susceptibility vs Concentration \nSystem Size (L): {20}, Interaction (J): {1} \nMonte Carlo Step: {1000}")
plt.xlabel("Concentration (x)")
plt.ylabel("Susceptibility")
plt.legend()
plt.grid()
plot_no += 1
plt.savefig(f'plots\\result-{plot_no}.png', bbox_inches='tight', dpi=150)
plt.show()
plt.clf()
